# %% [markdown]
# <a href="https://colab.research.google.com/github/willow788/Computer-Vision-Projects/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# !pip install opencv-python
# !pip install numpy
# !pip install Pillow

# %%
import streamlit as st
from PIL import Image
from io import BytesIO
import numpy as np
import cv2

#function to convert an image to watercolor image
def convert_to_watercolor_sketch(inp_img):
  img_1 = cv2.edgePreservingFilter(inp_img,
                                   flags=2,
                                   sigma_s=50,
                                   sigma_r=0.8)
  img_water_color = cv2.stylization(img_1,
                                    sigma_s= 100,
                                    sigma_r= 0.5)
  return (img_water_color)

#function to convert an image to pencil sketch
def pencilsketch(inp_img):
  img_sketch, pencil_color_sketch = cv2.pencilSketch(
      inp_img,
      sigma_s=60,
      sigma_r=0.07,
      shade_factor=0.087
  )
  return (img_sketch)

#function to load an image
def loading_an_img(image):
  img = Image.open(image)
  return img

#main function
def main():

  # basic heading and titles
  st.title('WEB APPLICATION TO CONVERT IMAGE TO SKETCH')
  st.write("This is an application developed for converting\
  your ***image*** to a ***Water Color Sketch*** OR ***Pencil Sketch***")
  st.subheader("Please Upload your image")

  # image file uploader
  image_file = st.file_uploader("Upload Images", type=["png", "jpg", "jpeg"])

  # if the image is uploaded then execute these
  # lines of code
  if image_file is not None:

    # select box (drop down to choose between water
    # color / pencil sketch)
    option = st.selectbox('How would you like to convert the image',
                          ('Convert to water color sketch',
                           'Convert to pencil sketch'))
    if option == 'Convert to water color sketch':
        image = Image.open(image_file)
        final_sketch = convert_to_watercolor_sketch(np.array(image))
        im_pil = Image.fromarray(final_sketch)

        # two columns to display the original image and the
        # image after applying water color sketching effect
        col1, col2 = st.columns(2)
        with col1:
            st.header("Original Image")
            st.image(loading_an_img(image_file), width=250)

        with col2:
            st.header("Water Color Sketch")
            st.image(im_pil, width=250)
            buf = BytesIO()
            img = im_pil
            img.save(buf, format="PNG") # Changed to PNG
            byte_im = buf.getvalue()
            st.download_button(
                label="Download image",
                data=byte_im,
                file_name="watercolorsketch.png",
                mime="image/png"
            )

    if option == 'Convert to pencil sketch':
        image = Image.open(image_file)
        final_sketch = pencilsketch(np.array(image))
        im_pil = Image.fromarray(final_sketch)

        # two columns to display the original image
        # and the image after applying
        # pencil sketching effect
        col1, col2 = st.columns(2)
        with col1:
            st.header("Original Image")
            st.image(loading_an_img(image_file), width=250)

        with col2:
            st.header("Pencil Sketch")
            st.image(im_pil, width=250)
            buf = BytesIO()
            img = im_pil
            img.save(buf, format="PNG") # Changed to PNG
            byte_im = buf.getvalue()
            st.download_button(
                label="Download image",
                data=byte_im,
                file_name="pencilsketch.png", # Changed filename for clarity
                mime="image/png"
            )


if __name__ == '__main__':
  main()
# Out:
# 2026-04-24 09:10:18.799 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-24 09:10:18.993
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-04-24 09:10:18.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-24 09:10:18.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-24 09:10:18.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-24 09:10:18.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-24 09:10:18.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# %%writefile app.py
import streamlit as st
from PIL import Image
from io import BytesIO
import numpy as np
import cv2

#function to convert an image to watercolor image
def convert_to_watercolor_sketch(inp_img):
  img_1 = cv2.edgePreservingFilter(inp_img,
                                   flags=2,
                                   sigma_s=50,
                                   sigma_r=0.8)
  img_water_color = cv2.stylization(img_1,
                                    sigma_s= 100,
                                    sigma_r= 0.5)
  return (img_water_color)

#function to convert an image to pencil sketch
def pencilsketch(inp_img):
  img_sketch, pencil_color_sketch = cv2.pencilSketch(
      inp_img,
      sigma_s=60,
      sigma_r=0.07,
      shade_factor=0.087
  )
  return (img_sketch)

#function to load an image
def loading_an_img(image):
  img = Image.open(image)
  return img

#main function
def main():

  # basic heading and titles
  st.title('WEB APPLICATION TO CONVERT IMAGE TO SKETCH')
  st.write("This is an application developed for converting\
  your ***image*** to a ***Water Color Sketch*** OR ***Pencil Sketch***")
  st.subheader("Please Upload your image")

  # image file uploader
  image_file = st.file_uploader("Upload Images", type=["png", "jpg", "jpeg"])

  # if the image is uploaded then execute these
  # lines of code
  if image_file is not None:

    # select box (drop down to choose between water
    # color / pencil sketch)
    option = st.selectbox('How would you like to convert the image',
                          ('Convert to water color sketch',
                           'Convert to pencil sketch'))
    if option == 'Convert to water color sketch':
        image = Image.open(image_file)
        final_sketch = convert_to_watercolor_sketch(np.array(image))
        im_pil = Image.fromarray(final_sketch)

        # two columns to display the original image and the
        # image after applying water color sketching effect
        col1, col2 = st.columns(2)
        with col1:
            st.header("Original Image")
            st.image(loading_an_img(image_file), width=250)

        with col2:
            st.header("Water Color Sketch")
            st.image(im_pil, width=250)
            buf = BytesIO()
            img = im_pil
            img.save(buf, format="PNG") # Changed to PNG
            byte_im = buf.getvalue()
            st.download_button(
                label="Download image",
                data=byte_im,
                file_name="watercolorsketch.png",
                mime="image/png"
            )

    if option == 'Convert to pencil sketch':
        image = Image.open(image_file)
        final_sketch = pencilsketch(np.array(image))
        im_pil = Image.fromarray(final_sketch)

        # two columns to display the original image
        # and the image after applying
        # pencil sketching effect
        col1, col2 = st.columns(2)
        with col1:
            st.header("Original Image")
            st.image(loading_an_img(image_file), width=250)

        with col2:
            st.header("Pencil Sketch")
            st.image(im_pil, width=250)
            buf = BytesIO()
            img = im_pil
            img.save(buf, format="PNG") # Changed to PNG
            byte_im = buf.getvalue()
            st.download_button(
                label="Download image",
                data=byte_im,
                file_name="pencilsketch.png", # Changed filename for clarity
                mime="image/png"
            )


if __name__ == '__main__':
  main()
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.13.114:8501
#
#   Stopping...

# %%
# Stopping the previous streamlit execution might be necessary if it's still running
# You might need to manually interrupt the cell above if it's stuck.

# %% [markdown]
# ### Using ngrok to expose the Streamlit app
#
# Sometimes, the direct external IP from Colab can be unstable or slow. We can use `ngrok` to create a stable, public URL for your Streamlit application.
#
# 1.  **Install ngrok:** This will install the ngrok command-line tool.
# 2.  **Run Streamlit with ngrok:** This will start your Streamlit app and tunnel it through ngrok, providing a new public URL.

# %%
# Install ngrok
# !pip install ngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 61.6 MB/s eta 0:00:00
# ...

# %%
# Start streamlit and ngrok
# !pip install pyngrok # Ensure pyngrok is installed
from pyngrok import ngrok
import subprocess
import os

# Terminate any existing ngrok tunnels
ngrok.kill()

# You can add your ngrok auth token here for more persistent tunnels or custom domains.
# If you don't have one, it might work for a limited time.
# UNCOMMENT THE LINE BELOW AND REPLACE "YOUR_NGROK_AUTH_TOKEN" WITH YOUR ACTUAL TOKEN
# ngrok.set_auth_token("YOUR_NGROK_AUTH_TOKEN")

# Start Streamlit in the background
print("Starting Streamlit app in background...")
process = subprocess = subprocess.Popen(["streamlit", "run", "app.py"])

# Give Streamlit a moment to start up
import time
time.sleep(5)

# Open a ngrok tunnel to Streamlit's default port 8501
public_url = ngrok.connect(8501)
print(f"Streamlit App URL: {public_url}")
# Out:
# ...
# Starting Streamlit app in background...
# ERROR:pyngrok.process.ngrok:t=2026-04-24T09:14:39+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_2255/1425809594.py in <cell line: 0>()
#      22
#      23 # Open a ngrok tunnel to Streamlit's default port 8501
# ---> 24 public_url = ngrok.connect(8501)
#      25 print(f"Streamlit App URL: {public_url}")
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     323     logger.info(f"Opening tunnel named: {name}")
#     324
# ...
